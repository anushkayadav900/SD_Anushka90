# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkayadav900/SD_Anushka90/blob/main/day_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("====student marksheet===")
name=input("Enter students name")

# %%
print("==== Student Marksheet ====")

name = input("Enter student's name: ")
roll = int(input("Enter roll number: "))
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))
english = int(input("Enter English marks: "))

student = {
    "Name": name,
    "Roll No": roll,
    "Maths": maths,
    "Science": science,
    "English": english
}

print("\n==== MARKSHEET ====")
print("Name:", student["Name"])
print("Roll No:", student["Roll No"])
print("Maths:", student["Maths"])
print("Science:", student["Science"])
print("English:", student["English"])

total=maths+science+english
percentage=total/3

print("")
# Out:
# ==== Student Marksheet ====
# Enter student's name: anu
# Enter roll number: 24
# Enter Maths marks: 56
# Enter Science marks: 67
# Enter English marks: 78
#
# ==== MARKSHEET ====
# Name: anu
# Roll No: 24
# Maths: 56
# Science: 67
# English: 78
