# %%
print("==== Student Marksheet ====")

name = input("Enter student's name: ")
roll = int(input("Enter roll number: "))
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))
english = int(input("Enter English marks: "))

student = {
    "Name": name,
    "Roll No": roll,
    "Maths": maths,
    "Science": science,
    "English": english
}

print("\n==== MARKSHEET ====")
print("Name:", student["Name"])
print("Roll No:", student["Roll No"])
print("Maths:", student["Maths"])
print("Science:", student["Science"])
print("English:", student["English"])

total=maths+science+english
percentage=total/3

print("Total",total)
print("Percentage",percentage)
# Out:
# ==== Student Marksheet ====
# Enter student's name: anu
# Enter roll number: 71
# Enter Maths marks: 80
# Enter Science marks: 87
# Enter English marks: 86
#
# ==== MARKSHEET ====
# Name: anu
# Roll No: 71
# Maths: 80
# Science: 87
# English: 86
# Total 253
# Percentage 84.33333333333333

# %%
name=input("Enter Your Name : ")
l=[]
i=0
sum=0
while(i<6):
  l.append(int(input("Enter Your Subject Score : ")))
  i+=1
print()
print("="*40)
print()
print("*"*10," Student MarkSheet ","*"*10)
print()
print("="*40)
print()
for j in l :
  sum+=i
  if(j > 89):
    print("obtained Number : " ,j," Grade: A+")
  elif(j > 80 and j <90):
    print("obtained Number : " ,j," Grade: A")
  elif(j > 70 and j <80):
    print("obtained Number : " ,j," Grade: B+")
  elif(j > 60 and j <70):
    print("obtained Number : " ,j," Grade: B")
  else:
   print("obtained Number : " ,j," Grade: Fail",)
# Out:
# Enter Your Name : anu
# Enter Your Subject Score : 90
# Enter Your Subject Score : 98
# Enter Your Subject Score : 8
# Enter Your Subject Score : 67
# Enter Your Subject Score : 56
# Enter Your Subject Score : 76
#
# ...
#
# **********  Student MarkSheet  **********
#
# ...
#
# obtained Number :  90  Grade: A+
# obtained Number :  98  Grade: A+
# obtained Number :  8  Grade: Fail
# obtained Number :  67  Grade: B
# obtained Number :  56  Grade: Fail
# obtained Number :  76  Grade: B+
